# %% [markdown]
# # Grupo 2 : Mariu Andrade & Mauricio Rumbea
#
# Modulo 3

# %%
OPENAI_KEY = " "

# %% [markdown]
# # Proyecto:

# %%
import pandas as pd
df = pd.read_csv("lahistoriaec.csv")

# %%
#max display columns

pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    contributors  coordinates                      created_at  favorite_count  \
# 0           NaN          NaN  Sat Nov 21 14:18:24 +0000 2020              16
# 1           NaN          NaN  Sat Nov 21 05:07:50 +0000 2020              53
# 2           NaN          NaN  Sat Nov 21 04:41:09 +0000 2020             290
# 3           NaN          NaN  Sat Nov 21 04:25:33 +0000 2020              85
# 4           NaN          NaN  Sat Nov 21 02:37:17 +0000 2020              18
#
#    favorited  geo                   id               id_str  \
# 0      False  NaN  1330153595493343241  1330153595493343241
# 1      False  NaN  1330015039873560577  1330015039873560577
# 2      False  NaN  1330008325455556609  1330008325455556609
# 3      False  NaN  1330004396420296704  1330004396420296704
# 4      False  NaN  1329977153572794369  1329977153572794369
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# ...

# %%
df['text'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 400 entries, 0 to 399
# Series name: text
# Non-Null Count  Dtype
# --------------  -----
# 400 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %%
df['text'].isna().sum()
# Out:
# 0

# %%
df['text'].drop_duplicates()
# Out:
# 0      Después de la censura, vagancia. La caricatura...
# 1      Corte de Justicia de #Napo ratificó sentencia ...
# 2      Búsqueda implacable. La @PoliciaEcuador allanó...
# 3      Trabajadores de empresa de limpieza que dan se...
# 4      Empresa de educación de Estados Unidos abrió s...
# 5      Los "alvaristas" siguen haciendo a diario plan...
# 6      El reguetonero #Wisin pide perdón por el machi...
# 7      La Defensoría del Pueblo @DEFENSORIAEC publica...
# 8      Se suspendió la Teletón Ecuador 2020 según el ...
# 9      Para la producción de @NuestraSiembra –y como ...
# 10     Presos de cárceles El Rodeo de #Portoviejo y d...
# 11     Un like inapropiado. El administrador de la cu...
# 12     "Le taparon toda la cabeza y le torturaron dán...
# 13     Tortura y muerte en centro de rehabilitación c...
# 14     Albanés fue asesinado con seis disparos de fus...
# 15     El bien comido, la caricatura de la política d...
# ...

# %%
df['text'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 400 entries, 0 to 399
# Series name: text
# Non-Null Count  Dtype
# --------------  -----
# 400 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %%
df.shape
# Out:
# (400, 223)

# %%
# display max rows

pd.set_option('display.max_rows', None)
df.dtypes
# Out:
# contributors                                                float64
# coordinates                                                 float64
# created_at                                                   object
# favorite_count                                                int64
# favorited                                                      bool
# geo                                                         float64
# id                                                            int64
# id_str                                                        int64
# in_reply_to_screen_name                                      object
# in_reply_to_status_id                                       float64
# in_reply_to_status_id_str                                   float64
# in_reply_to_user_id                                         float64
# in_reply_to_user_id_str                                     float64
# is_quote_status                                                bool
# ...

# %% [markdown]
# Proyecto.
# Desafío 1 Realizar un análisis exploratorio de datos utilizando chatGPT
# 1. Cual es el intervalo de días en donde hay tweets?
# 2. Cuantos tweets hay por día? Cuantos tweets hay en total?
# 3. Cuantos retweets hay por día? likes por dia?
# 4. Cuales son los percentiles de la distribución de las variables: retuit y "likes"?
# 5. Cual es la distrbución por días de la semana y horas del día de las variables retuit y likes?
# Copie los prompts y los resultados en un archivo.

# %%
df.retweet_count.sum()
# Out:
# 23997

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## 1. Cual es el intervalo de días en donde hay tweets?

# %% [markdown]
# Prompt: Eres un científico de datos, que recibes este df con la informacion de tweets de una cuenta. Haz un primer analisis e indical el intervalo de dias en donde hay tweets.
#
# Respuesta: El intervalo de días en el que hay tweets en la cuenta es desde el 11 de noviembre de 2020 hasta el 22 de noviembre de 2020.

# %% [markdown]
# ## 2. Cuantos tweets hay por día? Cuantos tweets hay en total?

# %% [markdown]
# Prompt: Cual es el total de tweets por día y cual es el total ? genera un grafico de la distribución
#
# Respuesta: El total de tweets en el periodo analizado es de 400. La distribución de tweets por día es la siguiente:

# %%
img1 = mpimg.imread('output 1.png')  # Cambia por la ruta de tu imagen
plt.imshow(img1)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 3. Cuantos retweets hay por día? likes por dia?

# %% [markdown]
# Prompt: Cual es el total de retweets y likes por día, cual es el total. Genera un grafico para la distribución por día. grafica los retweets con barras y los likes con lineas.
#
# Respuesta: El total de retweets en el periodo analizado es de 23,997, mientras que el total de likes (favoritos) es de 43,186.
#
# El gráfico muestra la distribución diaria de retweets y likes, donde se puede observar la variación en la interacción de los tweets a lo largo del tiempo.
#
# ![output (6).png](<attachment:output (6).png>)

# %%
img2 = mpimg.imread('output 2.png')  # Cambia por la ruta de tu imagen
plt.imshow(img2)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 4. Cuales son los percentiles de la distribución de las variables: retuit y "likes"?

# %% [markdown]
# Prompt: Cuales son los percentiles de la distribucion de los retweets y likes por dia? el grafico tiene que ser de los percentiles de retweets y likes por día. es para el equipo de estadisticas de una agencia.
#
# Respuesta:
#
# Aquí tienes un gráfico de los percentiles de retweets y likes, diseñado para el equipo de estadísticas de la agencia.
#
# Descripción del gráfico:
#
# Curva roja (Retweets) muestra la distribución de los percentiles de retweets.
# Curva azul (Likes) representa los percentiles de likes.
# Etiquetas en cada punto, indicando los valores específicos para una mejor interpretación.
# Ejes bien definidos, con los percentiles clave (25%, 50%, 75%, 90%, 95%, 99%) etiquetados para una fácil lectura.
# Diseño limpio y profesional, con una cuadrícula ligera para mejorar la visualización de las tendencias.
# Este gráfico permite analizar la distribución de la interacción, identificar valores atípicos y ayudar a la toma de decisiones basadas en datos estadísticos.

# %%
img3 = mpimg.imread('output 3.png')  # Cambia por la ruta de tu imagen
plt.imshow(img3)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 5. Cual es la distribución por días de la semana y horas del día de las variables retuit y likes?

# %% [markdown]
# Prompt: Cual es la distribución por días de la semana y horas del día de las variables retweets y likes? genera un mapa de calor para combinar los dos resultados. en el eje x coloca los dias de la semana
#
# Respuesta:

# %%
imgs = ['output 4.png', 'output 5.png']
plt.figure(figsize=(10, 5))

for i, img in enumerate(imgs, 1):
    plt.subplot(1, 2, i)
    plt.imshow(plt.imread(img))
    plt.axis('off')

plt.show()

# %% [markdown]
# # Desafío 2 del proyecto

# %%
opinions = df["text"].values
resultado = ", ".join(f'"{elemento}"' for elemento in opinions)

# %%
from openai import OpenAI


client = OpenAI(
  organization='org-8AghacFhYbrLH96uY8obz0Z2',
  project='proj_IWuNJKJuCbFd4ZOh6IOldtkB',
  api_key = OPENAI_KEY
)

# %%
import openai


# Configuración de la API
openai.api_key = OPENAI_KEY
messages = []
messages.append({
     "role": "system",
      "content": "Eres un periodista reconocido en Ecuador. Trabajas para una agencia de comunicación"
})

# %%
messages.append({
     "role": "user",
      "content": "Ayudame a resumir las siguientes noticias: " + resultado
})

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)
assistant_message = response.choices[0].message

# %%
assistant_message
# Out:
# ChatCompletionMessage(content='Aquí tienes un resumen de las últimas noticias:\n\n1. **Política y Justicia en Ecuador**:\n   - La Corte de Justicia de Napo ratificó una sentencia de prisión y multa por un caso de desacato.\n   - Protestas de seguidores de Álvaro Noboa exigen su candidatura presidencial en el CNE.\n   - La Defensoría del Pueblo denunció violaciones a los derechos de un periodista.\n   - La ministra de Gobierno, María Paula Romo, enfrentará un juicio político en la Asamblea.\n   - Denuncias de fraude y nepotismo afectan el ámbito político ecuatoriano.\n\n2. **Policía y Crimen**:\n   - La policía realiza allanamientos y detenciones por narcotráfico y tráfico de personas en varias provincias.\n   - Una pareja comete asaltos armados en Quito, intensificándose la búsqueda policial.\n   - Instituciones penitenciarias enfrentan problemas de corrupción y tráfico en sus instalaciones.\n\n3. **Cultura y Sociedad**:\n   - Inicia el Festival de Artes Vivas de Loja, mayormente de 
# ...

# %% [markdown]
# 'Aquí tienes un resumen de las últimas noticias
# 1. **Política y Justicia en Ecuador**
#    - La Corte de Justicia de Napo ratificó una sentencia de prisión y multa por un caso de desacato
#    - Protestas de seguidores de Álvaro Noboa exigen su candidatura presidencial en el CNE
#    - La Defensoría del Pueblo denunció violaciones a los derechos de un periodista
#    - La ministra de Gobierno, María Paula Romo, enfrentará un juicio político en la Asamblea
#    - Denuncias de fraude y nepotismo afectan el ámbito político ecuatoriano
# 2. **Policía y Crimen**
#    - La policía realiza allanamientos y detenciones por narcotráfico y tráfico de personas en varias provincias
#    - Una pareja comete asaltos armados en Quito, intensificándose la búsqueda policial
#    - Instituciones penitenciarias enfrentan problemas de corrupción y tráfico en sus instalaciones
# 3. **Cultura y Sociedad**
#    - Inicia el Festival de Artes Vivas de Loja, mayormente de forma virtual
#    - La pandemia afecta severamente al sector cultural, con un 89% de trabajadores perdiendo ingresos
#    - San Andrés en Colombia enfrenta olas gigantes por el huracán Iota
# 4. **Economía y Protestas Laborales**
#    - Trabajadores de limpieza de un hospital en Quito protestan por falta de pagos
#    - Una empresa de EE.UU. busca profesores latinoamericanos como parte de un programa de contratación
# 5. **Internacional**
#    - Francisco Sagasti es nombrado presidente de Perú tras la crisis política
#    - Protestas en Guatemala contra el presupuesto del Congreso terminan en incendios
# 6. **Deportes y Entretenimiento**
#    - Éxitos en el deporte ecuatoriano con victorias en ciclismo y fútbol
#    - Netflix lanza la nueva temporada de "The Crown", generando gran interés
# Estos resúmenes incluyen temas clave de interés nacional e internacional, destacando la tensión política, el trabajo de las fuerzas policiales contra el crimen, los retos culturales y económicos en tiempos de pandemia, y eventos relevantes en la región.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None)
